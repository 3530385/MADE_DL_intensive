# %% [markdown]
# # Train model

# %%
# !python train.py
# Out:
#      epoch      loss       gpu
#       1/50     3.614   0.0629G: 100%|████████| 468/468 [00:03<00:00, 137.25it/s]
#
#      epoch      loss       gpu
#       1/50     16.27   0.0629G: 100%|████████| 104/104 [00:00<00:00, 518.93it/s]
#
#      epoch      loss       gpu
#       2/50     3.269   0.0629G: 100%|████████| 468/468 [00:02<00:00, 164.93it/s]
#
#      epoch      loss       gpu
#       2/50     14.71   0.0629G: 100%|████████| 104/104 [00:00<00:00, 536.94it/s]
#
#      epoch      loss       gpu
#       3/50     3.236   0.0629G: 100%|████████| 468/468 [00:02<00:00, 156.85it/s]
#
#      epoch      loss       gpu
#       3/50     14.56   0.0629G: 100%|████████| 104/104 [00:00<00:00, 570.07it/s]
#
#      epoch      loss       gpu
#       4/50     2.791   0.0629G: 100%|████████| 468/468 [00:02<00:00, 160.82it/s]
#
#      epoch      loss       gpu
#       4/50     12.56   0.0629G: 100%|████████| 104/104 [00:00<00:00, 520.64it/s]
#
#      epoch      loss       gpu
# ...

# %% [markdown]
# # Recognize image

# %%
# !python recognize.py --image_path 2cegf.png
# Out:
# Ground truth: 2cegf
# Prediction: 2cegf

# %% [markdown]
# # Calculate CER

# %%
from torchmetrics import CharErrorRate
from recognize import calc_cer

cer = calc_cer("samples/","weights/weights.pth")
print(f"{cer=}")
# Out:
# cer=0.04634615406394005
